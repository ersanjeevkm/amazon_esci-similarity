# %%
import pandas as pd

df_products = pd.read_csv('/kaggle/input/amazon-esci-small/amazon_esci_products_small.csv')

# %%
# !pip install -q faiss-cpu sentence-transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 55.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.3 MB/s eta 0:00:0000:0100:01

# %%
from sentence_transformers import SentenceTransformer
jinaai = SentenceTransformer("jinaai/jina-embeddings-v2-small-en", trust_remote_code=True)
e5 = SentenceTransformer("intfloat/multilingual-e5-small", trust_remote_code=True)
# Out:
# 2025-06-23 18:21:08.254418: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750702868.476542      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750702868.546880      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/70.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# ...

# %%
def generate_embedding(text, locale='en'):
    if locale == 'en':        
        sentences = ["This is a test sentence."]
        embeddings = jinaai.encode(sentences, normalize_embeddings=True)
        return embeddings
    else:
        sentences = ["!solid camiseta sin manga"]
        embeddings = e5.encode(sentences, normalize_embeddings=True)
        return embeddings

# %%
embeddings = generate_embedding("", "jp")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_products['context'] = (
    "Product Title:" + df_products['product_title'].astype(str) +
    "\nProduct Description:" + df_products['product_description'].astype(str) +
    "\nProduct Bullet Points:" + df_products['product_bullet_point'].astype(str) +
    "\nProduct Brand:" + df_products['product_brand'].astype(str) +
    "\nProduct Color:" + df_products['product_color'].astype(str)
)

# %%
def format_input(row):
    if row[]
    return f"passage: {row['title']} {row['context']}"  # Adjust as needed

# %%
tqdm.pandas()
# df_products['combined_text'] = df_products.progress_apply(format_input, axis=1)

# Batch encode
embeddings = model.encode(df_products['combined_text'].tolist(), show_progress_bar=True, batch_size=64)

# Save embeddings back to DataFrame
df_products['embedding'] = embeddings.tolist()

# %% [markdown]
# https://chatgpt.com/c/68599e94-77c8-8001-8a89-68c7457849fd
